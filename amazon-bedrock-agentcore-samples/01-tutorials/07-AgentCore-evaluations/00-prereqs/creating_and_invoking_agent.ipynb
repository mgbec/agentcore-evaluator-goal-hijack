# %% [markdown]
# # Prerequisites: Creating Sample Agents
#
# ## Overview
#
# Let's first start by creating agents to be evaluated. This tutorial creates two sample agents for evaluation using different frameworks:
# - [Strands Agents SDK](https://strandsagents.com/)
# - [LangGraph](https://www.langchain.com/langgraph)
#
# Both agents uses Anthropic Claude Haiku 4.5 from Amazon Bedrock as the LLM model but you can use any model of your preference and they have identical capabilities:
# - **Math Tool**: Tool to perform basic math operations
# - **Weather Tool**: Dummy implementation for weather tool
#
#
# The architecture looks as following:
#
# ![Architecture](../images/agent_architecture.png)
#
# ## Prerequisites
# - Python 3.10+
# - AWS credentials

# %%
# !pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: boto3>=1.42.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from -r ../requirements.txt (line 1)) (1.42.25)
# Requirement already satisfied: strands-agents in /home/mom/anaconda3/lib/python3.13/site-packages (from -r ../requirements.txt (line 2)) (1.12.0)
# Requirement already satisfied: strands-agents-tools in /home/mom/anaconda3/lib/python3.13/site-packages (from -r ../requirements.txt (line 3)) (0.2.8)
# Requirement already satisfied: ipywidgets in /home/mom/anaconda3/lib/python3.13/site-packages (from -r ../requirements.txt (line 4)) (8.1.7)
# Requirement already satisfied: bedrock-agentcore-starter-toolkit>=0.2.4 in /home/mom/anaconda3/lib/python3.13/site-packages (from -r ../requirements.txt (line 5)) (0.2.5)
# Requirement already satisfied: botocore<1.43.0,>=1.42.25 in /home/mom/anaconda3/lib/python3.13/site-packages (from boto3>=1.42.0->-r ../requirements.txt (line 1)) (1.42.25)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/mom/anaconda3/lib/python3.13/site-packages (from boto3>=1.42.0->-r ../requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from boto3>=1.42.0->-r ../requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/mom/anaconda3/lib/python3.13/site-packages (from botocore<1.43.0,>=1.42.25->boto3>=1.42.0->-r ../requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/mom/anaconda3/lib/python3.13/site-packages (from botocore<1.43.0,>=1.42.25->boto3>=1.42.0->-r ../requirements.txt (line 1)) (2.5.0)
# Requirement already satisfied: six>=1.5 in /home/mom/anaconda3/lib/python3.13/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.43.0,>=1.42.25->boto3>=1.42.0->-r ../requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /home/mom/anaconda3/lib/python3.13/site-packages (from strands-agents->-r ../requirements.txt (line 2)) (0.17.0)
# Requirement already satisfied: mcp<2.0.0,>=1.11.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from strands-agents->-r ../requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.30.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from strands-agents->-r ../requirements.txt (line 2)) (1.37.0)
# Requirement already satisfied: opentelemetry-instrumentation-threading<1.00b0,>=0.51b0 in /home/mom/anaconda3/lib/python3.13/site-packages (from strands-agents->-r ../requirements.txt (line 2)) (0.58b0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.30.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from strands-agents->-r ../requirements.txt (line 2)) (1.37.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.4.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from strands-agents->-r ../requirements.txt (line 2)) (2.12.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.13.2 in /home/mom/anaconda3/lib/python3.13/site-packages (from strands-agents->-r ../requirements.txt (line 2)) (4.15.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from strands-agents->-r ../requirements.txt (line 2)) (6.0.0)
# Requirement already satisfied: anyio>=4.5 in /home/mom/anaconda3/lib/python3.13/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r ../requirements.txt (line 2)) (4.11.0)
# Requirement already satisfied: httpx-sse>=0.4 in /home/mom/anaconda3/lib/python3.13/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r ../requirements.txt (line 2)) (0.4.3)
# Requirement already satisfied: httpx>=0.27.1 in /home/mom/anaconda3/lib/python3.13/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r ../requirements.txt (line 2)) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r ../requirements.txt (line 2)) (4.25.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /home/mom/anaconda3/lib/python3.13/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r ../requirements.txt (line 2)) (2.11.0)
# Requirement already satisfied: python-multipart>=0.0.9 in /home/mom/anaconda3/lib/python3.13/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r ../requirements.txt (line 2)) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /home/mom/anaconda3/lib/python3.13/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r ../requirements.txt (line 2)) (3.0.2)
# Requirement already satisfied: starlette>=0.27 in /home/mom/anaconda3/lib/python3.13/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r ../requirements.txt (line 2)) (0.48.0)
# Requirement already satisfied: uvicorn>=0.31.1 in /home/mom/anaconda3/lib/python3.13/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r ../requirements.txt (line 2)) (0.37.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from opentelemetry-api<2.0.0,>=1.30.0->strands-agents->-r ../requirements.txt (line 2)) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /home/mom/anaconda3/lib/python3.13/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2.0.0,>=1.30.0->strands-agents->-r ../requirements.txt (line 2)) (3.23.0)
# Requirement already satisfied: opentelemetry-instrumentation==0.58b0 in /home/mom/anaconda3/lib/python3.13/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r ../requirements.txt (line 2)) (0.58b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r ../requirements.txt (line 2)) (1.17.3)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /home/mom/anaconda3/lib/python3.13/site-packages (from opentelemetry-instrumentation==0.58b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r ../requirements.txt (line 2)) (0.58b0)
# Requirement already satisfied: packaging>=18.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from opentelemetry-instrumentation==0.58b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r ../requirements.txt (line 2)) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents->-r ../requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /home/mom/anaconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents->-r ../requirements.txt (line 2)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/mom/anaconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents->-r ../requirements.txt (line 2)) (0.4.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from strands-agents-tools->-r ../requirements.txt (line 3)) (3.13.0)
# Requirement already satisfied: aws-requests-auth<0.5.0,>=0.4.3 in /home/mom/anaconda3/lib/python3.13/site-packages (from strands-agents-tools->-r ../requirements.txt (line 3)) (0.4.3)
# Requirement already satisfied: dill<0.5.0,>=0.4.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from strands-agents-tools->-r ../requirements.txt (line 3)) (0.4.0)
# Requirement already satisfied: markdownify<2.0.0,>=1.0.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from strands-agents-tools->-r ../requirements.txt (line 3)) (1.2.0)
# Requirement already satisfied: pillow<12.0.0,>=11.2.1 in /home/mom/anaconda3/lib/python3.13/site-packages (from strands-agents-tools->-r ../requirements.txt (line 3)) (11.3.0)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.51 in /home/mom/anaconda3/lib/python3.13/site-packages (from strands-agents-tools->-r ../requirements.txt (line 3)) (3.0.52)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in /home/mom/anaconda3/lib/python3.13/site-packages (from strands-agents-tools->-r ../requirements.txt (line 3)) (2.10.1)
# Requirement already satisfied: readabilipy<1.0.0,>=0.2.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from strands-agents-tools->-r ../requirements.txt (line 3)) (0.3.0)
# Requirement already satisfied: requests<3.0.0,>=2.28.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from strands-agents-tools->-r ../requirements.txt (line 3)) (2.32.5)
# Requirement already satisfied: rich<15.0.0,>=14.0.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from strands-agents-tools->-r ../requirements.txt (line 3)) (14.2.0)
# Requirement already satisfied: slack-bolt<2.0.0,>=1.23.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from strands-agents-tools->-r ../requirements.txt (line 3)) (1.25.0)
# Requirement already satisfied: sympy<2.0.0,>=1.12.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from strands-agents-tools->-r ../requirements.txt (line 3)) (1.14.0)
# Requirement already satisfied: tenacity<10.0.0,>=9.1.2 in /home/mom/anaconda3/lib/python3.13/site-packages (from strands-agents-tools->-r ../requirements.txt (line 3)) (9.1.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r ../requirements.txt (line 3)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r ../requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r ../requirements.txt (line 3)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/mom/anaconda3/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r ../requirements.txt (line 3)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/mom/anaconda3/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r ../requirements.txt (line 3)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r ../requirements.txt (line 3)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r ../requirements.txt (line 3)) (1.22.0)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in /home/mom/anaconda3/lib/python3.13/site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r ../requirements.txt (line 3)) (4.14.2)
# Requirement already satisfied: soupsieve>1.2 in /home/mom/anaconda3/lib/python3.13/site-packages (from beautifulsoup4<5,>=4.9->markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r ../requirements.txt (line 3)) (2.8)
# Requirement already satisfied: wcwidth in /home/mom/anaconda3/lib/python3.13/site-packages (from prompt-toolkit<4.0.0,>=3.0.51->strands-agents-tools->-r ../requirements.txt (line 3)) (0.2.14)
# Requirement already satisfied: html5lib in /home/mom/anaconda3/lib/python3.13/site-packages (from readabilipy<1.0.0,>=0.2.0->strands-agents-tools->-r ../requirements.txt (line 3)) (1.1)
# Requirement already satisfied: lxml in /home/mom/anaconda3/lib/python3.13/site-packages (from readabilipy<1.0.0,>=0.2.0->strands-agents-tools->-r ../requirements.txt (line 3)) (6.0.2)
# Requirement already satisfied: regex in /home/mom/anaconda3/lib/python3.13/site-packages (from readabilipy<1.0.0,>=0.2.0->strands-agents-tools->-r ../requirements.txt (line 3)) (2025.9.18)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/mom/anaconda3/lib/python3.13/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r ../requirements.txt (line 3)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/mom/anaconda3/lib/python3.13/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r ../requirements.txt (line 3)) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mom/anaconda3/lib/python3.13/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r ../requirements.txt (line 3)) (2025.10.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r ../requirements.txt (line 3)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r ../requirements.txt (line 3)) (2.19.2)
# Requirement already satisfied: slack_sdk<4,>=3.35.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from slack-bolt<2.0.0,>=1.23.0->strands-agents-tools->-r ../requirements.txt (line 3)) (3.36.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from sympy<2.0.0,>=1.12.0->strands-agents-tools->-r ../requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: comm>=0.1.3 in /home/mom/anaconda3/lib/python3.13/site-packages (from ipywidgets->-r ../requirements.txt (line 4)) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from ipywidgets->-r ../requirements.txt (line 4)) (9.6.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/mom/anaconda3/lib/python3.13/site-packages (from ipywidgets->-r ../requirements.txt (line 4)) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/mom/anaconda3/lib/python3.13/site-packages (from ipywidgets->-r ../requirements.txt (line 4)) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/mom/anaconda3/lib/python3.13/site-packages (from ipywidgets->-r ../requirements.txt (line 4)) (3.0.15)
# Requirement already satisfied: autopep8>=2.3.2 in /home/mom/anaconda3/lib/python3.13/site-packages (from bedrock-agentcore-starter-toolkit>=0.2.4->-r ../requirements.txt (line 5)) (2.3.2)
# Requirement already satisfied: bedrock-agentcore>=1.1.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from bedrock-agentcore-starter-toolkit>=0.2.4->-r ../requirements.txt (line 5)) (1.1.4)
# Requirement already satisfied: jinja2>=3.1.6 in /home/mom/anaconda3/lib/python3.13/site-packages (from bedrock-agentcore-starter-toolkit>=0.2.4->-r ../requirements.txt (line 5)) (3.1.6)
# Requirement already satisfied: openapi-spec-validator>=0.7.2 in /home/mom/anaconda3/lib/python3.13/site-packages (from bedrock-agentcore-starter-toolkit>=0.2.4->-r ../requirements.txt (line 5)) (0.7.2)
# Requirement already satisfied: prance>=25.4.8.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from bedrock-agentcore-starter-toolkit>=0.2.4->-r ../requirements.txt (line 5)) (25.4.8.0)
# Requirement already satisfied: py-openapi-schema-to-json-schema>=0.0.3 in /home/mom/anaconda3/lib/python3.13/site-packages (from bedrock-agentcore-starter-toolkit>=0.2.4->-r ../requirements.txt (line 5)) (0.0.3)
# Requirement already satisfied: pyyaml>=6.0.2 in /home/mom/anaconda3/lib/python3.13/site-packages (from bedrock-agentcore-starter-toolkit>=0.2.4->-r ../requirements.txt (line 5)) (6.0.3)
# Requirement already satisfied: questionary>=2.1.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from bedrock-agentcore-starter-toolkit>=0.2.4->-r ../requirements.txt (line 5)) (2.1.1)
# Requirement already satisfied: ruamel-yaml>=0.18.14 in /home/mom/anaconda3/lib/python3.13/site-packages (from bedrock-agentcore-starter-toolkit>=0.2.4->-r ../requirements.txt (line 5)) (0.18.15)
# Requirement already satisfied: toml>=0.10.2 in /home/mom/anaconda3/lib/python3.13/site-packages (from bedrock-agentcore-starter-toolkit>=0.2.4->-r ../requirements.txt (line 5)) (0.10.2)
# Requirement already satisfied: typer>=0.16.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from bedrock-agentcore-starter-toolkit>=0.2.4->-r ../requirements.txt (line 5)) (0.19.2)
# Requirement already satisfied: sniffio>=1.1 in /home/mom/anaconda3/lib/python3.13/site-packages (from anyio>=4.5->mcp<2.0.0,>=1.11.0->strands-agents->-r ../requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: pycodestyle>=2.12.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from autopep8>=2.3.2->bedrock-agentcore-starter-toolkit>=0.2.4->-r ../requirements.txt (line 5)) (2.14.0)
# Requirement already satisfied: websockets>=12.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from bedrock-agentcore>=1.1.0->bedrock-agentcore-starter-toolkit>=0.2.4->-r ../requirements.txt (line 5)) (16.0)
# Requirement already satisfied: httpcore==1.* in /home/mom/anaconda3/lib/python3.13/site-packages (from httpx>=0.27.1->mcp<2.0.0,>=1.11.0->strands-agents->-r ../requirements.txt (line 2)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/mom/anaconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.27.1->mcp<2.0.0,>=1.11.0->strands-agents->-r ../requirements.txt (line 2)) (0.16.0)
# Requirement already satisfied: decorator in /home/mom/anaconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets->-r ../requirements.txt (line 4)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /home/mom/anaconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets->-r ../requirements.txt (line 4)) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/mom/anaconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets->-r ../requirements.txt (line 4)) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /home/mom/anaconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets->-r ../requirements.txt (line 4)) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /home/mom/anaconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets->-r ../requirements.txt (line 4)) (4.9.0)
# Requirement already satisfied: stack_data in /home/mom/anaconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets->-r ../requirements.txt (line 4)) (0.6.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/mom/anaconda3/lib/python3.13/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->-r ../requirements.txt (line 4)) (0.8.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from jinja2>=3.1.6->bedrock-agentcore-starter-toolkit>=0.2.4->-r ../requirements.txt (line 5)) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/mom/anaconda3/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.11.0->strands-agents->-r ../requirements.txt (line 2)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/mom/anaconda3/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.11.0->strands-agents->-r ../requirements.txt (line 2)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/mom/anaconda3/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.11.0->strands-agents->-r ../requirements.txt (line 2)) (0.27.1)
# Requirement already satisfied: mdurl~=0.1 in /home/mom/anaconda3/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=14.0.0->strands-agents-tools->-r ../requirements.txt (line 3)) (0.1.2)
# Requirement already satisfied: jsonschema-path<0.4.0,>=0.3.1 in /home/mom/anaconda3/lib/python3.13/site-packages (from openapi-spec-validator>=0.7.2->bedrock-agentcore-starter-toolkit>=0.2.4->-r ../requirements.txt (line 5)) (0.3.4)
# Requirement already satisfied: lazy-object-proxy<2.0.0,>=1.7.1 in /home/mom/anaconda3/lib/python3.13/site-packages (from openapi-spec-validator>=0.7.2->bedrock-agentcore-starter-toolkit>=0.2.4->-r ../requirements.txt (line 5)) (1.12.0)
# Requirement already satisfied: openapi-schema-validator<0.7.0,>=0.6.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from openapi-spec-validator>=0.7.2->bedrock-agentcore-starter-toolkit>=0.2.4->-r ../requirements.txt (line 5)) (0.6.3)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in /home/mom/anaconda3/lib/python3.13/site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi-spec-validator>=0.7.2->bedrock-agentcore-starter-toolkit>=0.2.4->-r ../requirements.txt (line 5)) (0.4.4)
# Requirement already satisfied: rfc3339-validator in /home/mom/anaconda3/lib/python3.13/site-packages (from openapi-schema-validator<0.7.0,>=0.6.0->openapi-spec-validator>=0.7.2->bedrock-agentcore-starter-toolkit>=0.2.4->-r ../requirements.txt (line 5)) (0.1.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/mom/anaconda3/lib/python3.13/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets->-r ../requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: chardet>=5.2 in /home/mom/anaconda3/lib/python3.13/site-packages (from prance>=25.4.8.0->bedrock-agentcore-starter-toolkit>=0.2.4->-r ../requirements.txt (line 5)) (5.2.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from pydantic-settings>=2.5.2->mcp<2.0.0,>=1.11.0->strands-agents->-r ../requirements.txt (line 2)) (1.1.1)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /home/mom/anaconda3/lib/python3.13/site-packages (from ruamel-yaml>=0.18.14->bedrock-agentcore-starter-toolkit>=0.2.4->-r ../requirements.txt (line 5)) (0.2.14)
# Requirement already satisfied: click>=8.0.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from typer>=0.16.0->bedrock-agentcore-starter-toolkit>=0.2.4->-r ../requirements.txt (line 5)) (8.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from typer>=0.16.0->bedrock-agentcore-starter-toolkit>=0.2.4->-r ../requirements.txt (line 5)) (1.5.4)
# Requirement already satisfied: webencodings in /home/mom/anaconda3/lib/python3.13/site-packages (from html5lib->readabilipy<1.0.0,>=0.2.0->strands-agents-tools->-r ../requirements.txt (line 3)) (0.5.1)
# Requirement already satisfied: executing>=1.2.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from stack_data->ipython>=6.1.0->ipywidgets->-r ../requirements.txt (line 4)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/mom/anaconda3/lib/python3.13/site-packages (from stack_data->ipython>=6.1.0->ipywidgets->-r ../requirements.txt (line 4)) (3.0.0)
# Requirement already satisfied: pure-eval in /home/mom/anaconda3/lib/python3.13/site-packages (from stack_data->ipython>=6.1.0->ipywidgets->-r ../requirements.txt (line 4)) (0.2.3)
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Setup
#
# Import required packages and configure AWS session:

# %%
from bedrock_agentcore_starter_toolkit import Runtime
from boto3.session import Session
import uuid
import time

boto_session = Session()
region = boto_session.region_name
print(f"Using region: {region}")
# Out:
# Using region: us-west-2

# %% [markdown]
# ## Deploy Strands Agent
# Let's deploy our Strands Agents to AgentCore Runtime

# %%
agentcore_runtime = Runtime()

agent_name = "ac_eval_strands2"
response = agentcore_runtime.configure(
    entrypoint="eval_agent_strands.py",
    auto_create_execution_role=True,
    auto_create_ecr=True,
    requirements_file="requirements_strands.txt",
    region=region,
    agent_name=agent_name,
    idle_timeout=120
)
launch_result_strands = agentcore_runtime.launch()
print(f"Strands agent deployment started: {launch_result_strands}")
# Out:
# Entrypoint parsed: file=/home/mom/Desktop/02072026eval/amazon-bedrock-agentcore-samples/01-tutorials/07-AgentCore-evaluations/00-prereqs/eval_agent_strands.py, bedrock_agentcore_name=eval_agent_strands
# Memory disabled - agent will be stateless
# Configuring BedrockAgentCore agent: ac_eval_strands2
# Memory disabled
# Network mode: PUBLIC
# ⚠️ Platform mismatch: Current system is 'linux/amd64' but Bedrock AgentCore requires 'linux/arm64', so local builds
# won't work.
# Please use default launch command which will do a remote cross-platform build using code build.For deployment other
# options and workarounds, see:
# https://docs.aws.amazon.com/bedrock-agentcore/latest/devguide/getting-started-custom.html
# Generated Dockerfile: Dockerfile
# Generated .dockerignore: /home/mom/Desktop/02072026eval/amazon-bedrock-agentcore-samples/01-tutorials/07-AgentCore-evaluations/00-prereqs/.dockerignore
# Setting 'ac_eval_strands2' as default agent
# Bedrock AgentCore configured: /home/mom/Desktop/02072026eval/amazon-bedrock-agentcore-samples/01-tutorials/07-AgentCore-evaluations/00-prereqs/.bedrock_agentcore.yaml
# 🚀 Launching Bedrock AgentCore (cloud mode - RECOMMENDED)...
#    • Deploy Python code directly to runtime
#    • No Docker required (DEFAULT behavior)
#    • Production-ready deployment
#
# 💡 Deployment options:
#    • runtime.launch()                → Cloud (current)
#    • runtime.launch(local=True)      → Local development
# Memory disabled - skipping memory creation
# Starting CodeBuild ARM64 deployment for agent 'ac_eval_strands2' to account 339712707840 (us-west-2)
# Setting up AWS resources (ECR repository, execution roles)...
# Getting or creating ECR repository for agent: ac_eval_strands2
# ECR repository available: 339712707840.dkr.ecr.us-west-2.amazonaws.com/bedrock-agentcore-ac_eval_strands2
# Getting or creating execution role for agent: ac_eval_strands2
# Using AWS region: us-west-2, account ID: 339712707840
# Role name: AmazonBedrockAgentCoreSDKRuntime-us-west-2-a67917b625
# ✅ Reusing existing ECR repository: 339712707840.dkr.ecr.us-west-2.amazonaws.com/bedrock-agentcore-ac_eval_strands2
# ✅ Reusing existing execution role: arn:aws:iam::339712707840:role/AmazonBedrockAgentCoreSDKRuntime-us-west-2-a67917b625
# Execution role available: arn:aws:iam::339712707840:role/AmazonBedrockAgentCoreSDKRuntime-us-west-2-a67917b625
# Preparing CodeBuild project and uploading source...
# Getting or creating CodeBuild execution role for agent: ac_eval_strands2
# Role name: AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-a67917b625
# Reusing existing CodeBuild execution role: arn:aws:iam::339712707840:role/AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-a67917b625
# Using dockerignore.template with 46 patterns for zip filtering
# Uploaded source to S3: ac_eval_strands2/source.zip
# Updated CodeBuild project: bedrock-agentcore-ac_eval_strands2-builder
# Starting CodeBuild build (this may take several minutes)...
# Starting CodeBuild monitoring...
# 🔄 QUEUED started (total: 0s)
# ✅ QUEUED completed in 1.1s
# 🔄 PROVISIONING started (total: 1s)
# ✅ PROVISIONING completed in 7.9s
# 🔄 DOWNLOAD_SOURCE started (total: 9s)
# ✅ DOWNLOAD_SOURCE completed in 1.1s
# 🔄 BUILD started (total: 10s)
# ✅ BUILD completed in 17.1s
# 🔄 POST_BUILD started (total: 27s)
# ✅ POST_BUILD completed in 10.3s
# 🔄 COMPLETED started (total: 38s)
# ✅ COMPLETED completed in 1.1s
# 🎉 CodeBuild completed successfully in 0m 38s
# CodeBuild completed successfully
# CodeBuild project configuration saved
# Deploying to Bedrock AgentCore...
# Applying custom lifecycle settings: idle=120, max=None
# Agent created/updated: arn:aws:bedrock-agentcore:us-west-2:339712707840:runtime/ac_eval_strands2-4U1R8Y4JF0
# Observability is enabled, configuring observability components...
# CloudWatch Logs resource policy already configured
# X-Ray trace destination already configured
# X-Ray indexing rule already configured
# Transaction Search already fully configured
# ObservabilityDeliveryManager initialized for region: us-west-2, account: 339712707840
# ✅ Logs auto-created by AWS for runtime/ac_eval_strands2-4U1R8Y4JF0
# ✅ Traces delivery enabled for runtime/ac_eval_strands2-4U1R8Y4JF0
# Observability enabled for runtime/ac_eval_strands2-4U1R8Y4JF0 - logs: True, traces: True
# ✅ X-Ray traces delivery enabled for agent ac_eval_strands2-4U1R8Y4JF0
# 🔍 GenAI Observability Dashboard:
#    https://console.aws.amazon.com/cloudwatch/home?region=us-west-2#gen-ai-observability/agent-core
# Polling for endpoint to be ready...
# Agent endpoint: arn:aws:bedrock-agentcore:us-west-2:339712707840:runtime/ac_eval_strands2-4U1R8Y4JF0/runtime-endpoint/DEFAULT
# Deployment completed successfully - Agent: arn:aws:bedrock-agentcore:us-west-2:339712707840:runtime/ac_eval_strands2-4U1R8Y4JF0
# Built with CodeBuild: bedrock-agentcore-ac_eval_strands2-builder:d4d52566-eaff-48e5-bf29-cdc27415cf4c
# Deployed to cloud: arn:aws:bedrock-agentcore:us-west-2:339712707840:runtime/ac_eval_strands2-4U1R8Y4JF0
# ECR image: 339712707840.dkr.ecr.us-west-2.amazonaws.com/bedrock-agentcore-ac_eval_strands2
# 🔍 Agent logs available at:
#    /aws/bedrock-agentcore/runtimes/ac_eval_strands2-4U1R8Y4JF0-DEFAULT --log-stream-name-prefix "2026/02/07/\[runtime-logs]"
#    /aws/bedrock-agentcore/runtimes/ac_eval_strands2-4U1R8Y4JF0-DEFAULT --log-stream-names "otel-rt-logs"
# 💡 Tail logs with: aws logs tail /aws/bedrock-agentcore/runtimes/ac_eval_strands2-4U1R8Y4JF0-DEFAULT --log-stream-name-prefix "2026/02/07/\[runtime-logs]" --follow
# 💡 Or view recent logs: aws logs tail /aws/bedrock-agentcore/runtimes/ac_eval_strands2-4U1R8Y4JF0-DEFAULT --log-stream-name-prefix "2026/02/07/\[runtime-logs]" --since 1h
# Strands agent deployment started: mode='codebuild' tag='bedrock_agentcore-ac_eval_strands2:latest' env_vars=None port=None runtime=None ecr_uri='339712707840.dkr.ecr.us-west-2.amazonaws.com/bedrock-agentcore-ac_eval_strands2' agent_id='ac_eval_strands2-4U1R8Y4JF0' agent_arn='arn:aws:bedrock-agentcore:us-west-2:339712707840:runtime/ac_eval_strands2-4U1R8Y4JF0' codebuild_id='bedrock-agentcore-ac_eval_strands2-builder:d4d52566-eaff-48e5-bf29-cdc27415cf4c' build_output=None

# %% [markdown]
# ### Check status for deployment on AgentCore Runtime
# Wait for deployment to be in ACTIVE status..

# %%
def wait_for_deployment(runtime, name):
    end_statuses = ['READY', 'CREATE_FAILED', 'DELETE_FAILED', 'UPDATE_FAILED']
    while True:
        status_response = runtime.status()
        status = status_response.endpoint['status']
        print(f"{name} status: {status}")
        if status in end_statuses:
            print(f"{name} deployment completed with status: {status}")
            return status
        time.sleep(10)

strands_status = wait_for_deployment(agentcore_runtime, "Strands")
# Out:
# Retrieved Bedrock AgentCore status for: ac_eval_strands2
# Strands status: READY
# Strands deployment completed with status: READY

# %% [markdown]
# ### Invoke the Strands Agents on Runtime
# Let's test the Strands agent by invoking the AgentCore Runtime endpoint with a payload.

# %%
session_id_strands = str(uuid.uuid4())
print(f"Session ID: {session_id_strands}")
# Out:
# Session ID: f8da8ce8-b155-42a7-a967-2d91151ca9eb

# %%
invoke_response = agentcore_runtime.invoke(
    payload={"prompt": "How much is 2+2?"},
    session_id=session_id_strands
)
invoke_response
# Out:
# {'ResponseMetadata': {'RequestId': '249c7457-6465-4b18-a702-7ee64984bd05',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'date': 'Sat, 07 Feb 2026 18:32:06 GMT',
#    'content-type': 'application/json',
#    'transfer-encoding': 'chunked',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': '249c7457-6465-4b18-a702-7ee64984bd05',
#    'baggage': 'Self=1-69878523-64688c4409d0c9ad4982dbc1,session.id=f8da8ce8-b155-42a7-a967-2d91151ca9eb',
#    'x-amzn-bedrock-agentcore-runtime-session-id': 'f8da8ce8-b155-42a7-a967-2d91151ca9eb',
#    'x-amzn-trace-id': 'Root=1-69878523-57dadb192eead12847ce2db9;Parent=79073c66ba6d2d8e;Sampled=1;Self=1-69878523-64688c4409d0c9ad4982dbc1'},
#   'RetryAttempts': 0},
#  'runtimeSessionId': 'f8da8ce8-b155-42a7-a967-2d91151ca9eb',
#  'traceId': 'Root=1-69878523-57dadb192eead12847ce2db9;Parent=79073c66ba6d2d8e;Sampled=1;Self=1-69878523-64688c4409d0c9ad4982dbc1',
#  'baggage': 'Self=1-69878523-64688c4409d0c9ad4982dbc1,session.id=f8da8ce8-b155-42a7-a967-2d91151ca9eb',
#  'contentType': 'application/json',
#  'statusCode': 200,
#  'response': ['2 + 2 = **4**']}

# %%
invoke_response = agentcore_runtime.invoke(
    payload={"prompt": "How is the weather now?"},
    session_id=session_id_strands
)
invoke_response
# Out:
# {'ResponseMetadata': {'RequestId': '6771b1a5-6282-46cc-990e-0571f3370209',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'date': 'Sat, 07 Feb 2026 18:32:13 GMT',
#    'content-type': 'application/json',
#    'transfer-encoding': 'chunked',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': '6771b1a5-6282-46cc-990e-0571f3370209',
#    'baggage': 'Self=1-6987852b-5bfc4fd131556f4a0bdbc52d,session.id=f8da8ce8-b155-42a7-a967-2d91151ca9eb',
#    'x-amzn-bedrock-agentcore-runtime-session-id': 'f8da8ce8-b155-42a7-a967-2d91151ca9eb',
#    'x-amzn-trace-id': 'Root=1-6987852b-5b3f237707d669240f59bdc6;Parent=f386ec261c0d5780;Sampled=1;Self=1-6987852b-5bfc4fd131556f4a0bdbc52d'},
#   'RetryAttempts': 0},
#  'runtimeSessionId': 'f8da8ce8-b155-42a7-a967-2d91151ca9eb',
#  'traceId': 'Root=1-6987852b-5b3f237707d669240f59bdc6;Parent=f386ec261c0d5780;Sampled=1;Self=1-6987852b-5bfc4fd131556f4a0bdbc52d',
#  'baggage': 'Self=1-6987852b-5bfc4fd131556f4a0bdbc52d,session.id=f8da8ce8-b155-42a7-a967-2d91151ca9eb',
#  'contentType': 'application/json',
#  'statusCode': 200,
#  'response': ['The weather is currently **sunny**! ☀️']}

# %%
invoke_response = agentcore_runtime.invoke(
    payload={"prompt": "Can you tell me the capital of the US?"},
    session_id=session_id_strands
)
invoke_response
# Out:
# {'ResponseMetadata': {'RequestId': '2e59fead-ea54-45a6-84bf-91ead694c042',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'date': 'Sat, 07 Feb 2026 18:32:20 GMT',
#    'content-type': 'application/json',
#    'transfer-encoding': 'chunked',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': '2e59fead-ea54-45a6-84bf-91ead694c042',
#    'baggage': 'Self=1-69878532-115b58fa3aecd2ba043aa65f,session.id=f8da8ce8-b155-42a7-a967-2d91151ca9eb',
#    'x-amzn-bedrock-agentcore-runtime-session-id': 'f8da8ce8-b155-42a7-a967-2d91151ca9eb',
#    'x-amzn-trace-id': 'Root=1-69878532-7f9685bf469e1dd91e8da733;Parent=0ac1f63d97bdaaaa;Sampled=1;Self=1-69878532-115b58fa3aecd2ba043aa65f'},
#   'RetryAttempts': 0},
#  'runtimeSessionId': 'f8da8ce8-b155-42a7-a967-2d91151ca9eb',
#  'traceId': 'Root=1-69878532-7f9685bf469e1dd91e8da733;Parent=0ac1f63d97bdaaaa;Sampled=1;Self=1-69878532-115b58fa3aecd2ba043aa65f',
#  'baggage': 'Self=1-69878532-115b58fa3aecd2ba043aa65f,session.id=f8da8ce8-b155-42a7-a967-2d91151ca9eb',
#  'contentType': 'application/json',
#  'statusCode': 200,
#  'response': ['The capital of the United States is **Washington, D.C.** (District of Columbia).\n\nWashington, D.C. is located on the eastern coast of the United States and is home to the U.S. Capitol, the White House, and many other important government institutions and landmarks.']}

# %% [markdown]
# ## Deploy LangGraph Agent to AgentCore Runtime
#
# Let's also deploy our LangGraph agent to AgentCore Runtime.

# %%
langgraph_agentcore_runtime = Runtime()
agent_name = "ac_eval_langgraph2"
response = langgraph_agentcore_runtime.configure(
    entrypoint="eval_agent_langgraph.py",
    auto_create_execution_role=True,
    auto_create_ecr=True,
    requirements_file="requirements_langgraph.txt",
    region=region,
    agent_name=agent_name,
    idle_timeout=120
)
launch_result_langgraph = langgraph_agentcore_runtime.launch()
print(f"LangGraph agent deployment started: {launch_result_langgraph}")
# Out:
# Entrypoint parsed: file=/home/mom/Desktop/02072026eval/amazon-bedrock-agentcore-samples/01-tutorials/07-AgentCore-evaluations/00-prereqs/eval_agent_langgraph.py, bedrock_agentcore_name=eval_agent_langgraph
# Memory disabled - agent will be stateless
# Configuring BedrockAgentCore agent: ac_eval_langgraph2
# Memory disabled
# Network mode: PUBLIC
# ⚠️ Platform mismatch: Current system is 'linux/amd64' but Bedrock AgentCore requires 'linux/arm64', so local builds
# won't work.
# Please use default launch command which will do a remote cross-platform build using code build.For deployment other
# options and workarounds, see:
# https://docs.aws.amazon.com/bedrock-agentcore/latest/devguide/getting-started-custom.html
# Generated Dockerfile: Dockerfile
# Generated .dockerignore: /home/mom/Desktop/02072026eval/amazon-bedrock-agentcore-samples/01-tutorials/07-AgentCore-evaluations/00-prereqs/.dockerignore
# Changing default agent from 'ac_eval_strands2' to 'ac_eval_langgraph2'
# Bedrock AgentCore configured: /home/mom/Desktop/02072026eval/amazon-bedrock-agentcore-samples/01-tutorials/07-AgentCore-evaluations/00-prereqs/.bedrock_agentcore.yaml
# 🚀 Launching Bedrock AgentCore (cloud mode - RECOMMENDED)...
#    • Deploy Python code directly to runtime
#    • No Docker required (DEFAULT behavior)
#    • Production-ready deployment
#
# 💡 Deployment options:
#    • runtime.launch()                → Cloud (current)
#    • runtime.launch(local=True)      → Local development
# Memory disabled - skipping memory creation
# Starting CodeBuild ARM64 deployment for agent 'ac_eval_langgraph2' to account 339712707840 (us-west-2)
# Setting up AWS resources (ECR repository, execution roles)...
# Getting or creating ECR repository for agent: ac_eval_langgraph2
# ECR repository available: 339712707840.dkr.ecr.us-west-2.amazonaws.com/bedrock-agentcore-ac_eval_langgraph2
# Getting or creating execution role for agent: ac_eval_langgraph2
# Using AWS region: us-west-2, account ID: 339712707840
# Role name: AmazonBedrockAgentCoreSDKRuntime-us-west-2-a18a56d054
# ✅ Reusing existing ECR repository: 339712707840.dkr.ecr.us-west-2.amazonaws.com/bedrock-agentcore-ac_eval_langgraph2
# ✅ Reusing existing execution role: arn:aws:iam::339712707840:role/AmazonBedrockAgentCoreSDKRuntime-us-west-2-a18a56d054
# Execution role available: arn:aws:iam::339712707840:role/AmazonBedrockAgentCoreSDKRuntime-us-west-2-a18a56d054
# Preparing CodeBuild project and uploading source...
# Getting or creating CodeBuild execution role for agent: ac_eval_langgraph2
# Role name: AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-a18a56d054
# Reusing existing CodeBuild execution role: arn:aws:iam::339712707840:role/AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-a18a56d054
# Using dockerignore.template with 46 patterns for zip filtering
# Uploaded source to S3: ac_eval_langgraph2/source.zip
# Updated CodeBuild project: bedrock-agentcore-ac_eval_langgraph2-builder
# Starting CodeBuild build (this may take several minutes)...
# Starting CodeBuild monitoring...
# 🔄 QUEUED started (total: 0s)
# ✅ QUEUED completed in 1.1s
# 🔄 PROVISIONING started (total: 1s)
# ✅ PROVISIONING completed in 7.9s
# 🔄 DOWNLOAD_SOURCE started (total: 9s)
# ✅ DOWNLOAD_SOURCE completed in 2.3s
# 🔄 BUILD started (total: 11s)
# ✅ BUILD completed in 15.9s
# 🔄 POST_BUILD started (total: 27s)
# ✅ POST_BUILD completed in 10.3s
# 🔄 COMPLETED started (total: 38s)
# ✅ COMPLETED completed in 1.1s
# 🎉 CodeBuild completed successfully in 0m 38s
# CodeBuild completed successfully
# CodeBuild project configuration saved
# Deploying to Bedrock AgentCore...
# Applying custom lifecycle settings: idle=120, max=None
# Agent created/updated: arn:aws:bedrock-agentcore:us-west-2:339712707840:runtime/ac_eval_langgraph2-mZw4hcGHHr
# Observability is enabled, configuring observability components...
# CloudWatch Logs resource policy already configured
# X-Ray trace destination already configured
# X-Ray indexing rule already configured
# Transaction Search already fully configured
# ObservabilityDeliveryManager initialized for region: us-west-2, account: 339712707840
# ✅ Logs auto-created by AWS for runtime/ac_eval_langgraph2-mZw4hcGHHr
# ✅ Traces delivery enabled for runtime/ac_eval_langgraph2-mZw4hcGHHr
# Observability enabled for runtime/ac_eval_langgraph2-mZw4hcGHHr - logs: True, traces: True
# ✅ X-Ray traces delivery enabled for agent ac_eval_langgraph2-mZw4hcGHHr
# 🔍 GenAI Observability Dashboard:
#    https://console.aws.amazon.com/cloudwatch/home?region=us-west-2#gen-ai-observability/agent-core
# Polling for endpoint to be ready...
# Agent endpoint: arn:aws:bedrock-agentcore:us-west-2:339712707840:runtime/ac_eval_langgraph2-mZw4hcGHHr/runtime-endpoint/DEFAULT
# Deployment completed successfully - Agent: arn:aws:bedrock-agentcore:us-west-2:339712707840:runtime/ac_eval_langgraph2-mZw4hcGHHr
# Built with CodeBuild: bedrock-agentcore-ac_eval_langgraph2-builder:08c0a806-b4b7-41da-8963-728c17d7ef10
# Deployed to cloud: arn:aws:bedrock-agentcore:us-west-2:339712707840:runtime/ac_eval_langgraph2-mZw4hcGHHr
# ECR image: 339712707840.dkr.ecr.us-west-2.amazonaws.com/bedrock-agentcore-ac_eval_langgraph2
# 🔍 Agent logs available at:
#    /aws/bedrock-agentcore/runtimes/ac_eval_langgraph2-mZw4hcGHHr-DEFAULT --log-stream-name-prefix "2026/02/07/\[runtime-logs]"
#    /aws/bedrock-agentcore/runtimes/ac_eval_langgraph2-mZw4hcGHHr-DEFAULT --log-stream-names "otel-rt-logs"
# 💡 Tail logs with: aws logs tail /aws/bedrock-agentcore/runtimes/ac_eval_langgraph2-mZw4hcGHHr-DEFAULT --log-stream-name-prefix "2026/02/07/\[runtime-logs]" --follow
# 💡 Or view recent logs: aws logs tail /aws/bedrock-agentcore/runtimes/ac_eval_langgraph2-mZw4hcGHHr-DEFAULT --log-stream-name-prefix "2026/02/07/\[runtime-logs]" --since 1h
# LangGraph agent deployment started: mode='codebuild' tag='bedrock_agentcore-ac_eval_langgraph2:latest' env_vars=None port=None runtime=None ecr_uri='339712707840.dkr.ecr.us-west-2.amazonaws.com/bedrock-agentcore-ac_eval_langgraph2' agent_id='ac_eval_langgraph2-mZw4hcGHHr' agent_arn='arn:aws:bedrock-agentcore:us-west-2:339712707840:runtime/ac_eval_langgraph2-mZw4hcGHHr' codebuild_id='bedrock-agentcore-ac_eval_langgraph2-builder:08c0a806-b4b7-41da-8963-728c17d7ef10' build_output=None

# %% [markdown]
# ### Check the status of LangGraph agent
# Now that we've deployed the LangGraph agent to AgentCore Runtime, let's check for it's deployment status

# %%
langgraph_status = wait_for_deployment(langgraph_agentcore_runtime, "LangGraph")
# Out:
# Retrieved Bedrock AgentCore status for: ac_eval_langgraph2
# LangGraph status: READY
# LangGraph deployment completed with status: READY

# %% [markdown]
# ### Invoke the Langgraph Agent on Runtime
# Test the LangGraph agent endpoint on AgentCore Runtime with a payload:

# %%
session_id_langgraph = str(uuid.uuid4())
print(f"Session ID: {session_id_langgraph}")
# Out:
# Session ID: 57d90dac-4c01-4dce-a4c1-7dd167841dd5

# %%
response = langgraph_agentcore_runtime.invoke(
    payload={"prompt": "What is 2+2?"},
    session_id=session_id_langgraph
)
print(response)
# Out:
# {'ResponseMetadata': {'RequestId': '7bcb6d44-0afb-481a-9e67-12e1c0e30c9c', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Sat, 07 Feb 2026 18:33:54 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'x-amzn-requestid': '7bcb6d44-0afb-481a-9e67-12e1c0e30c9c', 'baggage': 'Self=1-6987858f-4494846843fd133a2a2ff84d,session.id=57d90dac-4c01-4dce-a4c1-7dd167841dd5', 'x-amzn-bedrock-agentcore-runtime-session-id': '57d90dac-4c01-4dce-a4c1-7dd167841dd5', 'x-amzn-trace-id': 'Root=1-6987858f-7cefddfb6dafca1550ea63c4;Parent=cc9215be0eda953d;Sampled=1;Self=1-6987858f-4494846843fd133a2a2ff84d'}, 'RetryAttempts': 0}, 'runtimeSessionId': '57d90dac-4c01-4dce-a4c1-7dd167841dd5', 'traceId': 'Root=1-6987858f-7cefddfb6dafca1550ea63c4;Parent=cc9215be0eda953d;Sampled=1;Self=1-6987858f-4494846843fd133a2a2ff84d', 'baggage': 'Self=1-6987858f-4494846843fd133a2a2ff84d,session.id=57d90dac-4c01-4dce-a4c1-7dd167841dd5', 'contentType': 'application/json', 'statusCode': 200, 'response': ['2 + 2 = **4**']}

# %%
invoke_response = agentcore_runtime.invoke(
    payload={"prompt": "What is the weather now?"},
    session_id=session_id_langgraph
)
invoke_response
# Out:
# {'ResponseMetadata': {'RequestId': 'c60d8703-84bb-436d-aa39-1b6ba6b8a96a',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'date': 'Sat, 07 Feb 2026 18:34:01 GMT',
#    'content-type': 'application/json',
#    'transfer-encoding': 'chunked',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': 'c60d8703-84bb-436d-aa39-1b6ba6b8a96a',
#    'baggage': 'Self=1-69878597-3706f08f1d0a0aa10f0bfc61,session.id=57d90dac-4c01-4dce-a4c1-7dd167841dd5',
#    'x-amzn-bedrock-agentcore-runtime-session-id': '57d90dac-4c01-4dce-a4c1-7dd167841dd5',
#    'x-amzn-trace-id': 'Root=1-69878597-411a465105c849cd05b8aa3a;Parent=c7bb57a373d8eac0;Sampled=1;Self=1-69878597-3706f08f1d0a0aa10f0bfc61'},
#   'RetryAttempts': 0},
#  'runtimeSessionId': '57d90dac-4c01-4dce-a4c1-7dd167841dd5',
#  'traceId': 'Root=1-69878597-411a465105c849cd05b8aa3a;Parent=c7bb57a373d8eac0;Sampled=1;Self=1-69878597-3706f08f1d0a0aa10f0bfc61',
#  'baggage': 'Self=1-69878597-3706f08f1d0a0aa10f0bfc61,session.id=57d90dac-4c01-4dce-a4c1-7dd167841dd5',
#  'contentType': 'application/json',
#  'statusCode': 200,
#  'response': ["The weather right now is **sunny**! ☀️ It's a nice day out there."]}

# %%
invoke_response = agentcore_runtime.invoke(
    payload={"prompt": "Can you tell me the capital of the US?"},
    session_id=session_id_langgraph
)
invoke_response
# Out:
# {'ResponseMetadata': {'RequestId': 'd9c7be99-8634-4dfe-89c4-960f6a703b7d',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'date': 'Sat, 07 Feb 2026 18:34:09 GMT',
#    'content-type': 'application/json',
#    'transfer-encoding': 'chunked',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': 'd9c7be99-8634-4dfe-89c4-960f6a703b7d',
#    'baggage': 'Self=1-698785a0-59361f236d55f498006e7d79,session.id=57d90dac-4c01-4dce-a4c1-7dd167841dd5',
#    'x-amzn-bedrock-agentcore-runtime-session-id': '57d90dac-4c01-4dce-a4c1-7dd167841dd5',
#    'x-amzn-trace-id': 'Root=1-698785a0-773d946a456a9d0838489e43;Parent=a693ac65d68ee722;Sampled=1;Self=1-698785a0-59361f236d55f498006e7d79'},
#   'RetryAttempts': 0},
#  'runtimeSessionId': '57d90dac-4c01-4dce-a4c1-7dd167841dd5',
#  'traceId': 'Root=1-698785a0-773d946a456a9d0838489e43;Parent=a693ac65d68ee722;Sampled=1;Self=1-698785a0-59361f236d55f498006e7d79',
#  'baggage': 'Self=1-698785a0-59361f236d55f498006e7d79,session.id=57d90dac-4c01-4dce-a4c1-7dd167841dd5',
#  'contentType': 'application/json',
#  'statusCode': 200,
#  'response': ["The capital of the United States is **Washington, D.C.** (District of Columbia). It's located on the east coast along the Potomac River and is home to the U.S. federal government, including the White House, the Capitol Building, and the Supreme Court."]}

# %%
print(f"Strands: {launch_result_strands}, Session: {session_id_strands}")
print(f"LangGraph: {launch_result_langgraph}, Session: {session_id_langgraph}")
# Out:
# Strands: mode='codebuild' tag='bedrock_agentcore-ac_eval_strands2:latest' env_vars=None port=None runtime=None ecr_uri='339712707840.dkr.ecr.us-west-2.amazonaws.com/bedrock-agentcore-ac_eval_strands2' agent_id='ac_eval_strands2-4U1R8Y4JF0' agent_arn='arn:aws:bedrock-agentcore:us-west-2:339712707840:runtime/ac_eval_strands2-4U1R8Y4JF0' codebuild_id='bedrock-agentcore-ac_eval_strands2-builder:d4d52566-eaff-48e5-bf29-cdc27415cf4c' build_output=None, Session: f8da8ce8-b155-42a7-a967-2d91151ca9eb
# LangGraph: mode='codebuild' tag='bedrock_agentcore-ac_eval_langgraph2:latest' env_vars=None port=None runtime=None ecr_uri='339712707840.dkr.ecr.us-west-2.amazonaws.com/bedrock-agentcore-ac_eval_langgraph2' agent_id='ac_eval_langgraph2-mZw4hcGHHr' agent_arn='arn:aws:bedrock-agentcore:us-west-2:339712707840:runtime/ac_eval_langgraph2-mZw4hcGHHr' codebuild_id='bedrock-agentcore-ac_eval_langgraph2-builder:08c0a806-b4b7-41da-8963-728c17d7ef10' build_output=None, Session: 57d90dac-4c01-4dce-a4c1-7dd167841dd5

# %%
# %store launch_result_strands
# %store session_id_strands
# %store launch_result_langgraph
# %store session_id_langgraph
# Out:
# Stored 'launch_result_strands' (LaunchResult)
# Stored 'session_id_strands' (str)
# Stored 'launch_result_langgraph' (LaunchResult)
# Stored 'session_id_langgraph' (str)

# %% [markdown]
# ## Next Steps
#
# Now that you have all the required pre-requisites, let's go through the individual evaluation tutorials:
# Continue with the evaluation tutorials:
# - [01-creating-custom-evaluators](../01-creating-custom-evaluators/): Create custom evaluators
# - [02-running-evaluations](../02-running-evaluations/): Run on-demand and online evaluations
# - [03-advanced](../03-advanced/): : Advanced techniques and dashboards
